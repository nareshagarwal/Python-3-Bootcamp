# %% [markdown]
# # 🐍 Python, NumPy, Pandas, Matplotlib & Seaborn - Titanic Hands-on Exercise
# Using the Titanic dataset (`titanic.csv`). This exercise covers Python basics → NumPy → Pandas → Visualization.

# %% [markdown]
# ## 📥 Load Dataset
# Data is lying in DATA directory

# %%
import pandas as pd

# Code
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## 1️⃣ Python Basics

# %% [markdown]
# **Q1. Create a list of passenger categories (`who`) and print the first 5.**

# %%
# Out:
# ['man', 'woman', 'woman', 'woman', 'man']

# %% [markdown]
# **Q2. Write a function to check if a passenger’s age is above 18 (Adult/Child).**

# %%
# Out:
# Adult

# %% [markdown]
# ## 2️⃣ NumPy

# %% [markdown]
# **Q3. Convert the `age` column into a NumPy array and calculate mean, max, min.**

# %%
import numpy as np

# code
# Out:
# 29.69911764705882 80.0 0.42

# %% [markdown]
# **Q4. Normalize the `fare` column (scale between 0–1).**

# %%
# Out:
# [0.01415106 0.13913574 0.01546857 0.1036443  0.01571255]

# %% [markdown]
# ## 3️⃣ Pandas

# %% [markdown]
# **Q5. Display the number of passengers in each class (`class`).**

# %%
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %% [markdown]
# **Q6. Find the average age of male vs female passengers.**

# %%
# Out:
# sex
# female    27.915709
# male      30.726645
# Name: age, dtype: float64

# %% [markdown]
# **Q7. Create a new column `FamilySize = sibsp + parch + 1` and find the average survival rate by family size.**

# %%
# Out:
# FamilySize
# 1     0.303538
# 2     0.552795
# 3     0.578431
# 4     0.724138
# 5     0.200000
# 6     0.136364
# 7     0.333333
# 8     0.000000
# 11    0.000000
# Name: survived, dtype: float64

# %% [markdown]
# ## 4️⃣ Matplotlib

# %% [markdown]
# **Q8. Plot a histogram of passenger ages.**

# %%
import matplotlib.pyplot as plt

# code

# %% [markdown]
# ## 5️⃣ Seaborn

# %% [markdown]
# **Q9. Create a boxplot of `fare` by `class`.**

# %%
import seaborn as sns

# code

# %% [markdown]
# **Q10. Plot a heatmap of correlations between numeric columns.**

# %% [markdown]
# In your correlation heatmap:
#
# Correlation (r) ranges from -1 → +1.
#
# A negative value (–ve correlation) means:
# 🔹 When one variable increases, the other tends to decrease.
